# %% [markdown]
# # The Statistics of Uncertainty and the Grammar of Graphics
#
# ---

# %% [markdown]
# ### A General Framework for Uncertainty Visualization
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### What do you mean by the grammar of graphics?
#
# **Grammar, n.**
#
# *"The fundamental principles or rules of an art or science."*
#
# > Oxford English Dictionary, 2nd Ed.
#
# **Grammar of graphics, n.**
#
# *"A grammar of graphics is a tool that helps us describe the components of a graphic."*
#
# > Hadley Wickham (2010)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Ingredients of the Grammar of Graphics
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Is weight related to fuel economy?
#
# - Start with a question
# - Identify data:
#     - MPG and Weight are quantitative
# - Map to Channels
#     - MPG -> X
#     - Weight -> Y
# - Identify Marks:
#     - MPG/Weight -> point

# %% [markdown]
# #### Translating Into Altair
# ##### (data, channels, marks)
#
# |-----|-----|
# |---|---|
# |mpg: numeric | `alt.Chart(mtchars)` |
# |wt: numeric | `.encode(` |
# |wt -> x position | `x = 'wt',` |
# |mpg -> y position | `y = 'mpg',` |
# |  |`)`|
# | mark: circle | `.mark_circle()` |
#
# ![image.png](attachment:image.png)

# %% [markdown]
# |---|---|
# |---|---|
# |mpg: numeric | `alt.Chart(mtcars)` |
# |wt: numeric | `.encode(` |
# |mph: numeric | `x = 'wt',` |
# |cyl: numeric | `y = 'mpg',` |
# |wt: x position | `color = 'carb',` |
# |mpg: y position | `size = 'cyl'` |
# |carb: color | `)` |
# |cyl: size |  |
# |mark: circle | `.mark_circle()` |
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Parameter uncertainty
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)
