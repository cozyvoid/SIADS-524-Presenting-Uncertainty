# %% [markdown]
# # Statistical Concepts: Part 1
#
# ---

# %% [markdown]
# ### Key Terms:
#
# - Population, sample, sampling distribution
# - Standard deviation and standard error
# - Central limit theorem
# - Quantile

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Standard Deviation v. Standard Error

# %% [markdown]
# #### Standard Deviation of Populations
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Central Limit Theorem

# %% [markdown]
# #### Statistics Puzzle
#
# ![image.png](attachment:image.png)
#
# **Central Limit Theorem**
#
# *"...as $n$ becomes larger, the sampling distribution of the mean will approach normality even if the population shape is nonnormal."*
#
# - Bruce Thompson (2006), *Foundation of Behavioral Statistics*, p. 154

# %% [markdown]
# ### Quantile
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Quantile Properties
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Key points:
#
# - The focus of this lecture was on the statistical foundations of uncertainty.
# - It is important to develop rapid recall for these concepts, as these terms will be used in other lectures and assignments.
# - Of particular importance is to internalize the different ways we describe the variance of samples and sampling distributions.
