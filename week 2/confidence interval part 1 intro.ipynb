# %% [markdown]
# # The Confidence Interval Part 1: Introduction
#
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### What is a confidence interval?
#
# An expression of uncertainty around an estimate of a population parameter.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Factors That Influence How We Calculate CI's
#
# 1. The statistic of interest (mean, correlation, proportion, etc.)
# 2. The number of samples (single vs. multiple)
