# %% [markdown]
# # The Confidence Interval: Part 2
# ## Single samples
#
# ---

# %% [markdown]
# ### The Confidence Interval Recipe: Single sample
#
# 1. A statistic (mean, proportion, difference in means, difference in proportions, slopes, correlation coefficients, etc.)
# 2. A standard error (estimated analytically)
# 3. A sampling distribution assumption (standard normal, t-distribution)
# 4. A desired level of confidence (`66%`, `90%`, `95%`)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Calculating Confidence Intervals: Mean from a single sample
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
